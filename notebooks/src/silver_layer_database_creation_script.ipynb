# %%
# %sql
create database if not exists watermark_db location "/mnt/silver/watermark_db";
create database if not exists appdb_equiplink location "/mnt/silver/appdb_equiplink";
create database if not exists appdb_saleslink location "/mnt/silver/appdb_saleslink";
create database if not exists corporatedb location "/mnt/silver/corporatedb";
create database if not exists dwdb location "/mnt/silver/dwdb";
create database if not exists xdb location "/mnt/silver/xdb";
create database if not exists toromontcatdb location "/mnt/silver/toromontcatdb";
create database if not exists ccmdata location "/mnt/silver/ccmdata";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create table if not exists watermark_db.watermark_table
(
  table_name string,
  watermark_value timestamp
)
USING DELTA
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
